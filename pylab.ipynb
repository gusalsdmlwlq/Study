# %%
import pylab
import numpy as np

# %%
x = np.random.normal(size=(10000))
y = np.random.normal(size=(10000))
pylab.hist(x)
pylab.show()
pylab.plot(x)
pylab.show()
pylab.plot(x,"bo")
pylab.show()
pylab.plot(x,y,"bo")
pylab.show()
pylab.plot(x,y)
